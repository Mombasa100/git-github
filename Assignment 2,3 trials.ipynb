# %% [markdown]
# # Pandas

# %% [markdown]
#
#      1. show a breakdown of distance from home by job role and attrition
#      2. compare average monhtly income by education and attrition

# %%
# imports needed to complete the assignment

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## import file

# %%
data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Breakdown of distance from home by job role and attrition

# %%
data.groupby(['DistanceFromHome']).sum()
# Out:
#                    Age  DailyRate  Education  EmployeeCount  EmployeeNumber  \
# DistanceFromHome
# 1                 7707     170617        620            208          209362
# 2                 8123     161449        597            211          218540
# 3                 3017      68953        233             84           76511
# 4                 2354      53114        173             64           65947
# 5                 2250      57308        192             65           62447
# 6                 2216      46669        171             59           49314
# 7                 3179      67509        248             84           86119
# 8                 2933      60840        228             80           80844
# 9                 3078      64533        254             85           88298
# 10                3017      66361        263             86           97890
# 11                1087      32352         85             29           30510
# ...

# %%
data.groupby(['JobRole']).sum()
# Out:
#                              Age  DailyRate  DistanceFromHome  Education  \
# JobRole
# Healthcare Representative   5215     111907              1282        392
# Human Resources             1846      39412               425        150
# Laboratory Technician       8831     206324              2437        718
# Manager                     4770      79861               819        308
# Manufacturing Director      5553     115423              1375        420
# Research Director           3520      64196               675        250
# Research Scientist          9997     233705              2632        851
# Sales Executive            12026     261484              3149        983
# Sales Representative        2520      67342               719        210
#
#                            EmployeeCount  EmployeeNumber  \
# JobRole
# Healthcare Representative            131          140797
# Human Resources                       52           64289
# ...

# %%
data.groupby(['Attrition']).sum()
# Out:
#              Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# Attrition
# No         46313    1001818             10993       3609           1233
# Yes         7965     177836              2520        673            237
#
#            EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# Attrition
# No                1267100                     3417       81319
# Yes                239452                      584       15541
#
#            JobInvolvement  JobLevel  ...  RelationshipSatisfaction  \
# Attrition                            ...
# No                   3416      2646  ...                      3371
# Yes                   597       388  ...                       616
#
#            StandardHours  StockOptionLevel  TotalWorkingYears  \
# Attrition
# No                 98640              1042              14627
# Yes                18960               125               1954
#
#            TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# Attrition
# ...

# %% [markdown]
# ## Comparison between monthly income by education and attrition

# %%
data.groupby(["Education", "Attrition"])["MonthlyIncome"].sum()
# Out:
# Education  Attrition
# 1          No            823732
#            Yes           135165
# 2          No           1567482
#            Yes           188432
# 3          No           3255621
#            Yes           472254
# 4          No           2409857
#            Yes           309439
# 5          No            368076
#            Yes            29251
# Name: MonthlyIncome, dtype: int64

# %% [markdown]
# ###### Distribution of employees by distance from home,job role,attrition,education

# %%
data.DistanceFromHome.value_counts().plot.bar(figsize=(15,8), color = 'teal')
plt.title(' Distance From Home')
plt.xlabel('Job role')
plt.ylabel('Attrition')
plt.show()

# %% [markdown]
# #### explore attrition by age

# %%
plt.figure(figsize = (10,8))
sns.countplot(x = data.Age, hue = data.Attrition)
plt.title('Attrition by Age')
plt.show()

# %% [markdown]
# ### data for education

# %%
data.Education.value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
data.Education.value_counts().plot.barh(figsize=(10,6))
plt.xlabel('Number of employees')
plt.ylabel('Education')
plt.title('Education of Employees')
plt.show()

# %%
data.Education.value_counts().plot.pie(figsize=(10,6), startangle = 5, autopct='%1.1f%%')
plt.axis('equal')
plt.show()
